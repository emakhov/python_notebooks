# %% [markdown]
# <a href="https://colab.research.google.com/github/emakhov/python_notebooks/blob/master/tensorflow_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pwd
# Out:
# /content
